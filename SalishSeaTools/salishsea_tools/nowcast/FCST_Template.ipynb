# %% [markdown]
# # Salish Sea NEMO Model Daily Nowcast Figures for Sea Surface Height

# %% [markdown]
# # Set-up

# %%
from __future__ import division

import datetime
from glob import glob
import os

from IPython.core.display import HTML
import netCDF4 as nc

from salishsea_tools.nowcast import figures

# %matplotlib inline

# %%
def results_dataset(period, grid, results_dir):
    """Return the results dataset for period (e.g. 1h or 1d)
    and grid (e.g. grid_T, grid_U) from results_dir.
    """
    filename_pattern = 'SalishSea_{period}_*_{grid}.nc'
    filepaths = glob(os.path.join(results_dir, filename_pattern.format(period=period, grid=grid)))
    return nc.Dataset(filepaths[0])

# %%
run_date = datetime.date.today()
run_date = datetime.datetime(2014,11,25)

# Results dataset location
results_home = '/ocean/sallen/allen/research/MEOPAR/SalishSea/forecast/'
results_dir = os.path.join(results_home, run_date.strftime('%d%b%y').lower())

# %% [markdown]
# Load the results datasets:

# %%
grid_T_hr = results_dataset('1h', 'grid_T', results_dir)

# %%
bathy = nc.Dataset('/data/nsoontie/MEOPAR/NEMO-forcing/grid/bathy_meter_SalishSea2.nc')

# %% [markdown]
# Display the figures:

# %%
HTML('<h2>{:%d%b%y} Forecast Figures</h2>'.format(run_date))
# Out:
# <h2>25Nov14 Forecast Figures</h2>

# %% [markdown]
# ## Point Atkinson water levels

# %%
fig = figures.ssh_PtAtkinson(grid_T_hr)

# %%
fig = figures.PA_tidal_predictions(grid_T_hr)

# %% [markdown]
# Tidal predictions calculated with t_tide: http://www.eos.ubc.ca/~rich/#T_Tide

# %%
reload (figures)
fig = figures.compare_tidalpredictions_maxSSH('Point Atkinson', grid_T_hr,bathy)

# %% [markdown]
# To do:
#
# 1. Combine all the three repeated SSH plots at Point Atkinson into one.
# 2. Make ssh ranges consistent among plots.

# %% [markdown]
# ## Water levels at NOAA stations

# %% [markdown]
# Observed water levels from NOAA: http://tidesandcurrents.noaa.gov/stations.html?type=Water+Levels
#
# To do:
# 1. Add a map showing where these stations are...

# %%
reload(figures)
fig = figures.compare_water_levels(grid_T_hr, bathy)

# %% [markdown]
# ## Weather

# %% [markdown]
# Observations from Environment Canada data.
#
# To do:
# 1. Add modelled winds.
# 2. Add map showing where Sandheads is

# %%
fig = figures.Sandheads_winds(grid_T_hr)
