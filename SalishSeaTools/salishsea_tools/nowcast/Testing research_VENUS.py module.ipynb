# %% [markdown]
# This notebook is used to test the research_VENUS.py module.

# %% [markdown]
# ##Test research_VENUS.py

# %%
import matplotlib.pyplot as plt
import netCDF4 as nc
import numpy as np

from salishsea_tools import (
    nc_tools,
    viz_tools,
    tidetools,
)

from salishsea_tools.nowcast import figures
from salishsea_tools.nowcast import research_VENUS as V

# %matplotlib inline

# %%
filec='/data/dlatorne/MEOPAR/SalishSea/nowcast/11may15/VENUS_central_gridded.nc'
filee='/data/dlatorne/MEOPAR/SalishSea/nowcast/11may15/VENUS_east_gridded.nc'
filet='/data/dlatorne/MEOPAR/SalishSea/nowcast/11may15/SalishSea_1h_20150511_20150511_grid_T.nc'
fileb='/data/dlatorne/MEOPAR/NEMO-forcing/grid/bathy_meter_SalishSea2.nc'

grid_c=nc.Dataset(filec)
grid_e=nc.Dataset(filee)
grid_t=nc.Dataset(filet)
grid_b=nc.Dataset(fileb)

# %% [markdown]
# #Test the functions

# %%
station='Central'
V.plot_vel_NE_gridded(station, grid_c, figsize=(10, 16))

# %%
station='East'
V.plot_vel_NE_gridded(station, grid_c, figsize=(10,16))

# %%
V.compare_VENUS(station,grid_t, grid_b)
