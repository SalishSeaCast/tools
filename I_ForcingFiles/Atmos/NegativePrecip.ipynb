# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import netCDF4 as nc
import numpy as np
from salishsea_tools import nc_tools

# %%
fullsize = nc.Dataset('/ocean/sallen/allen/research/Meopar/Operational/oper_allvar_y2014m09d30.nc')
nc_tools.show_variables(fullsize)
temp = fullsize.variables['tair'][:]
flats = fullsize.variables['nav_lat'][:]
flons = fullsize.variables['nav_lon'][:]
fprec = fullsize.variables['precip'][:]
# Out:
# [u'atmpres', u'nav_lat', u'nav_lon', u'precip', u'qair', u'solar', u'tair', u'therm_rad', u'time_counter', u'u_wind', u'v_wind', u'x', u'y']

# %%
plt.pcolormesh(flons,flats,fprec[17])
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x6d376c8>

# %%
fprec[17].min()
# Out:
# -1.041664e-05

# %%
sssize = nc.Dataset('/ocean/sallen/allen/research/Meopar/Operational/oper_allvar_ss_y2014m09d30.nc')
nc_tools.show_variables(sssize)
temp = sssize.variables['tair'][:]
lats = sssize.variables['nav_lat'][:]
lons = sssize.variables['nav_lon'][:]
prec = sssize.variables['precip'][:]
# Out:
# [u'y', u'x', u'nav_lat', u'nav_lon', u'time_counter', u'u_wind', u'v_wind', u'therm_rad', u'qair', u'solar', u'precip', u'tair', u'atmpres']

# %%
plt.pcolormesh(lons,lats,prec[17])
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x425ab48>

# %%
prec[17].min()
# Out:
# -1.041664e-05

# %% [markdown]
# ######
