# %%
# %matplotlib inline
from matplotlib import pylab
import matplotlib.pyplot as plt
import netCDF4 as NC
import numpy as np

# %%
fT = NC.Dataset('../../../nemo-forcing/open_boundaries/source_files/bc4SA_extractedFromBCCBaseline.nc','r')

# %%
print fT.file_format
# Out:
# NETCDF3_CLASSIC

# %%
for dim in fT.dimensions.values():
     print dim
# Out:
# <type 'netCDF4.Dimension'>: name = 'xi_rho', size = 4
#
# <type 'netCDF4.Dimension'>: name = 'xi_u', size = 3
#
# <type 'netCDF4.Dimension'>: name = 'xi_v', size = 4
#
# <type 'netCDF4.Dimension'>: name = 'eta_rho', size = 15
#
# <type 'netCDF4.Dimension'>: name = 'eta_u', size = 15
#
# <type 'netCDF4.Dimension'>: name = 'eta_v', size = 14
#
# <type 'netCDF4.Dimension'>: name = 's_rho', size = 30
#
# <type 'netCDF4.Dimension'>: name = 'ocean_time', size = 336

# %%
for var in fT.variables.values():
    print var
# Out:
# <type 'netCDF4.Variable'>
# float64 ocean_time(ocean_time)
#     long_name: time since model initialization
#     units: seconds since 1990-01-01 00:00:00
#     calendar: gregorian
#     field: time, scalar, series
# unlimited dimensions:
# current shape = (336,)
#
# <type 'netCDF4.Variable'>
# float64 temp(ocean_time, s_rho, eta_rho, xi_rho)
#     long_name: potential temperature
#     units: Celsius
#     field: temperature, scalar, series
#     time: ocean_time
# unlimited dimensions:
# current shape = (336, 30, 15, 4)
#
# <type 'netCDF4.Variable'>
# float64 salt(ocean_time, s_rho, eta_rho, xi_rho)
#     long_name: salinity
#     units: PSU
#     field: salinity, scalar, series
#     time: ocean_time
# unlimited dimensions:
# current shape = (336, 30, 15, 4)
#
# <type 'netCDF4.Variable'>
# float64 zeta(ocean_time, eta_rho, xi_rho)
#     long_name: sea surface height
#     units: meter
#     field: SSH, scalar, series
#     time: ocean_time
# unlimited dimensions:
# ...

# %%
latR = fT.variables['lat_rho'][:]
lonR = fT.variables['lon_rho'][:]

# %%
import sys
sys.path.append('../../bathymetry')
import bathy_tools

# %%
fB = NC.Dataset('../../../nemo-forcing/grid/bathy_meter_SalishSea.nc','r')
D = fB.variables['Bathymetry'][:]
lat = fB.variables['nav_lat'][:]
lon = fB.variables['nav_lon'][:]

# %%
t=3
fig = bathy_tools.plot_colourmesh(
    fB, 'Salish Sea Bathymetry, '+str(arr[t]), 
    axis_limits=(-126.3, -122.15, 47.05, 51))
#plt.plot(lonR,latR,'kx')
plt.contourf(lonR,latR,fT.variables['salt'][t,29,:,:],np.arange(28,33,0.1),cmap='RdPu')
plt.xlim((-125.5,-124.0))
plt.ylim((48.0,49.0))
# Out:
# (48.0, 49.0)

# %%
zr = fT.variables['zr'][:]
plt.contourf(zr[0,:,:13,2])
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x27d0170>

# %%
salt = fT.variables['salt'][:]
plt.contourf(np.transpose(salt[:,:,4,2]))
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x3af1cb0>

# %%
salttest = fT.variables['salt'][:,15,7,1]

import datetime
test = fT.variables['ocean_time'][:]
start_time = datetime.datetime(1990,1,1,0,0,0) 
arr = np.array([start_time + datetime.timedelta(seconds=i) for i in test])    
plt.plot(arr,fT.variables['salt'][:,29,7,1],'r')
plt.plot(arr,fT.variables['salt'][:,15,7,1],'b')
plt.plot(arr,fT.variables['salt'][:,4,7,1],'g')
plt.plot(arr,fT.variables['salt'][:,29,14,1],'r:')
plt.plot(arr,fT.variables['salt'][:,15,14,1],'b:')
plt.plot(arr,fT.variables['salt'][:,4,14,1],'g:')

# %%
plt.figure(figsize=(15,15))
plt.subplot(10,1,1)
cbarmin = 28
cbarmax = 35
plt.contourf(fT.variables['salt'][0,20,:,:],range(cbarmin,cbarmax))
plt.subplot(10,1,2)
plt.contourf(fT.variables['salt'][1,20,:,:],range(cbarmin,cbarmax))
plt.subplot(10,1,3)
plt.contourf(fT.variables['salt'][2,20,:,:],range(cbarmin,cbarmax))
plt.subplot(10,1,4)
plt.contourf(fT.variables['salt'][3,20,:,:],range(cbarmin,cbarmax))
plt.subplot(10,1,5)
plt.contourf(fT.variables['salt'][4,20,:,:],range(cbarmin,cbarmax))
plt.subplot(10,1,6)
plt.contourf(fT.variables['salt'][5,20,:,:],range(cbarmin,cbarmax))
plt.subplot(10,1,7)
plt.contourf(fT.variables['salt'][6,20,:,:],range(cbarmin,cbarmax))
plt.subplot(10,1,8)
plt.contourf(fT.variables['salt'][7,20,:,:],range(cbarmin,cbarmax))
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xf5bd518>
