# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import netCDF4 as nc
import numpy as np
from salishsea_tools import nc_tools
from salishsea_tools import bathy_tools

# %%
bathy = nc.Dataset('../../../nemo-forcing/grid/bathy_meter_SalishSea2.nc', 'r+')
depths = bathy.variables['Bathymetry']

# %%
fig = bathy_tools.plot_colourmesh(
    bathy, 'Salish Sea Bathymetry', 
    axis_limits=(-126.3, -122.15, 47.05, 51))

# %%
plt.plot(range(20,75),-depths[897,20:75],'*-')
plt.plot(range(20,75),-depths[896,20:75],'*-')
plt.plot(range(20,75),-depths[895,20:75],'*-')
plt.plot(range(20,75),-depths[892,20:75],'*-')
plt.plot(range(20,75),-depths[890,20:75],'*-')
plt.plot(range(20,75),-depths[889,20:75],'*-')
plt.plot(range(20,75),-depths[888,20:75],'*-')

# %%
# in agreement with Kate, I get 37 to 48 as the boundary.  But the channel is moving rapidly 
# to the east.  So I actually need to run to 60.  So better go 32 to 62.
