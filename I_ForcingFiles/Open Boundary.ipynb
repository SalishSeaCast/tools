# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
import numpy as np
import netCDF4 as NC

# %%
levels = MaxNLocator(nbins=15).tick_values(0, 500.)
cmap = plt.get_cmap('copper')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)

plt.figure(figsize=(9,9))
axgeo=plt.axes()
axgeo.set_aspect(1./np.cos(49.0*np.pi/180.))
im = plt.pcolormesh(lon, lat, D, cmap=cmap, norm=norm)
# set the limits of the plot to the limits of the data
lmin = -125.
lmax = -122.4
plt.axis([lmin, lmax, 48., 48.+(lmax-lmin)*74.4/111.2])
plt.colorbar()
plt.title('Juan de Fuca Subdomain')

# %%
levels = MaxNLocator(nbins=15).tick_values(0, 100.)
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
plt.figure(figsize=(9,9))
im = plt.pcolormesh(D, cmap=cmap, norm=norm)
# set the limits of the plot to the limits of the data
lmin = 207-1
lmax = 227-1
jmin = 87-1
jmax = 107-1
plt.axis([lmin, lmax, jmin, jmax])
plt.colorbar()
plt.plot(217-1,97-1,'xw')
plt.title('Juan de Fuca Subdomain')

# %%
pylab.plot(D[:,0])
print D[190,0],D[189,0]
print lat[189,0], lon[189,0]
print D[266,0],D[267,0]
print lat[267,0],lon[267,0]
print D.max()
# Out:
# 11.0 --
# 48.3866 -124.689
# 4.0 --
# 48.6969 -124.95
# 428.0

# %%
print D[97-1,217-1]
print lat[97-1,217-1]
print lon[97-1,217-1]
# Out:
# 21.0
# 48.4364
# -123.258
