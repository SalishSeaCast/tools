# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
import numpy as np
import netCDF4 as NC

# %%
fB = NC.Dataset('../../nemo-forcing/grid/SubDom_bathy_meter_NOBCchancomp.nc','r')
D = fB.variables['Bathymetry'][:]
lat = fB.variables['nav_lat'][:]
lon = fB.variables['nav_lon'][:]
print fB.variables['Bathymetry']
# Out:
# <type 'netCDF4.Variable'>
# float32 Bathymetry(y, x)
#     units: metre
#     _FillValue: 0.0
# unlimited dimensions:
# current shape = (345, 398)

# %%
levels = MaxNLocator(nbins=15).tick_values(0, 500.)
cmap = plt.get_cmap('copper_r')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)

plt.figure(figsize=(9,9))
axgeo=plt.axes()
axgeo.set_aspect(1./np.cos(49.0*np.pi/180.))
im = plt.pcolormesh(lon, lat, D, cmap=cmap, norm=norm)
# set the limits of the plot to the limits of the data
lmin = -125.
lmax = -122.4
#lmin = -123.5
#lmax = -123.0
plt.axis([lmin, lmax, 48., 48.+(lmax-lmin)*74.4/111.2])
print lat[97-1,217-1],lon[97-1,217-1]
plt.colorbar()
plt.plot(lon[97-1,217-1],lat[97-1,217-1],'oy',ms=5)
plt.plot(lon[76-1,292-1],lat[76-1,292-1],'or',ms=5)
plt.plot(lon[231-1,239-1],lat[231-1,239-1],'ob',ms=5)
plt.plot(lon[68-1,218-1],lat[68-1,218-1],'og',ms=5)
plt.plot(lon[127-1,223-1],lat[127-1,223-1],'og',ms=5)
plt.plot(lon[108-1,217-1],lat[108-1,217-1],'om',ms=5)
plt.plot(lon[94-1,212-1],lat[94-1,212-1],'om',ms=5)


plt.title('Juan de Fuca Subdomain')
# Out:
# 48.4364 -123.258

# %%
levels = MaxNLocator(nbins=20).tick_values(0, 40.)
norm = BoundaryNorm(levels, ncolors=cmap.N)
plt.figure(figsize=(9,9))
im = plt.pcolormesh(D, cmap=cmap, norm=norm)
# set the limits of the plot to the limits of the data
ipt = 212
jpt = 94
s=10
imin = ipt-s-1
imax = ipt+s-1
jmin = jpt-s-1
jmax = jpt+s-1
plt.axis([imin, imax, jmin, jmax])
plt.colorbar()

plt.plot(ipt-1,jpt-1,'om')
print D[jpt-1,ipt-1]
print D[jmax:jmin:-1, imin:imax]
plt.title('Juan de Fuca Subdomain')
# Out:
# 20.0
# [[-- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- 32.0 36.0 43.0 42.0]
#  [-- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- 21.0 35.0 40.0 41.0]
#  [-- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- 4.0 33.0 35.0 37.0]
#  [-- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- 19.0 21.0 31.0 37.0]
#  [-- -- -- -- -- -- -- -- -- -- -- 4.0 4.0 7.0 11.0 4.0 8.0 17.0 36.0 38.0]
#  [-- -- -- -- -- -- -- -- -- 6.0 7.0 11.0 11.0 21.0 27.0 21.0 8.0 21.0 37.0
#   39.0]
#  [-- -- -- -- -- -- -- 4.0 6.0 15.0 18.0 23.0 23.0 29.0 34.0 28.0 9.0 15.0
#   20.0 37.0]
#  [-- -- -- -- -- -- -- 6.0 12.0 20.0 23.0 23.0 30.0 33.0 28.0 15.0 9.0 7.0
#   12.0 25.0]
#  [13.0 4.0 -- -- -- -- -- 9.0 16.0 15.0 15.0 14.0 23.0 28.0 22.0 13.0 6.0
#   6.0 12.0 20.0]
#  [30.0 14.0 7.0 4.0 -- -- 4.0 14.0 14.0 14.0 13.0 15.0 21.0 19.0 17.0 8.0
#   5.0 5.0 9.0 20.0]
#  [45.0 25.0 18.0 9.0 4.0 8.0 12.0 22.0 20.0 20.0 20.0 20.0 20.0 17.0 11.0
#   7.0 4.0 -- 9.0 20.0]
# ...

# %%
e=6
print ipt-1,jpt-1,D[ipt-1,jpt-1]
print D[ipt-e-1:ipt+e,jpt-e-1:jpt+e]
# Out:
# 238 230 36.0
# [[-- -- -- -- 7.0 24.0 11.0 4.0 4.0 16.0 35.0 46.0 28.0]
#  [-- -- -- -- 4.0 15.0 17.0 18.0 17.0 30.0 46.0 47.0 32.0]
#  [-- -- -- -- 13.0 23.0 23.0 24.0 29.0 31.0 38.0 41.0 13.0]
#  [-- -- -- -- 19.0 23.0 21.0 22.0 30.0 35.0 38.0 27.0 --]
#  [-- -- -- -- 22.0 25.0 25.0 28.0 35.0 37.0 17.0 -- --]
#  [-- -- -- 9.0 18.0 27.0 32.0 35.0 37.0 37.0 35.0 14.0 --]
#  [4.0 4.0 4.0 15.0 27.0 34.0 36.0 37.0 42.0 42.0 33.0 16.0 --]
#  [8.0 7.0 13.0 24.0 33.0 36.0 39.0 39.0 43.0 43.0 16.0 4.0 --]
#  [14.0 13.0 20.0 27.0 35.0 37.0 38.0 40.0 44.0 42.0 11.0 -- --]
#  [18.0 17.0 34.0 35.0 37.0 35.0 34.0 39.0 43.0 41.0 11.0 -- --]
#  [21.0 20.0 38.0 42.0 36.0 34.0 32.0 35.0 42.0 42.0 -- -- --]
#  [27.0 33.0 48.0 47.0 44.0 44.0 40.0 38.0 41.0 42.0 -- -- --]
#  [39.0 49.0 49.0 40.0 44.0 45.0 45.0 45.0 45.0 43.0 -- -- --]]

# %%
pylab.plot(D[:,0])
print D[190,0],D[189,0]
print lat[189,0], lon[189,0]
print D[266,0],D[267,0]
print lat[267,0],lon[267,0]
print D.max()
