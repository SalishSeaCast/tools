# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import netCDF4 as nc
import numpy as np
from salishsea_tools import bathy_tools
from salishsea_tools import nc_tools

# %%
bathy = nc.Dataset('../../nemo-forcing/grid/bathy_meter_SalishSea2.nc', 'r')
print bathy.file_format
# Out:
# NETCDF4

# %%
fig = bathy_tools.plot_colourmesh(
    bathy, 'NEMO - Salish Sea Bathymetry', 
    axis_limits=(-123.4, -122.9, 49., 49.3), colour_map='spectral', bins=30)

# %%
coords = nc.Dataset('../../nemo-forcing/grid/coordinates_seagrid_SalishSea.nc', 'r')
nc_tools.show_variables(coords)
# Out:
# [u'nav_lon', u'nav_lat', u'time', u'time_steps', u'glamt', u'glamu', u'glamv', u'glamf', u'gphit', u'gphiu', u'gphiv', u'gphif', u'e1t', u'e1u', u'e1v', u'e1f', u'e2t', u'e2u', u'e2v', u'e2f']

# %%
lat_f = coords.variables['gphif'][0]
lon_f = coords.variables['glamf'][0]
lon = bathy.variables['nav_lon']
lat = bathy.variables['nav_lat']
print lon_f.shape
# Out:
# (898, 398)

# %%
imin = 380; imax=480; jmin = 260; jmax = 380
plt.figure(figsize=(10,10))
plt.plot(lon[imin:imax,jmin:jmax], lat[imin:imax,jmin:jmax], 'or');
plt.plot(lon_f[imin:imax,jmin:jmax], lat_f[imin:imax,jmin:jmax], 'xb')
plt.xlim((-123.4, -122.9))
plt.ylim((49., 49.3))
print lon.shape
# Out:
# (898, 398)

# %%
plt.figure(figsize=(10,10))
plt.plot(lon[imin:imax,jmin:jmax], lat[imin:imax,jmin:jmax], 'or');
plt.plot(lon_f[imin:imax,jmin:jmax], lat_f[imin:imax,jmin:jmax], 'xb')
plt.xlim((-123.4, -122.5))
plt.ylim((49., 49.1))
# Out:
# (49.0, 49.1)
