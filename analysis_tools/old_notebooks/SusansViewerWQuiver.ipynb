# %%
# %matplotlib inline
from matplotlib import pylab
import matplotlib.pyplot as plt
import netCDF4 as NC
import numpy as np

# %%
fT = NC.Dataset('../Basic6/5mn_grid_T.nc','r')
eta = fT.variables['sossheig'][:]
sal = fT.variables['vosaline'][:]
temp = fT.variables['votemper'][:]
depth = fT.variables['deptht'][:]
m = sal == 0
sal_masked = np.ma.array(sal,mask=m)
print sal_masked[1,0,375,250:255].mask
mt = temp == 0
temp_masked = np.ma.array(temp,mask=mt)
# Out:
# [False False False False False]

# %%
fU = NC.Dataset('../Basic6/5mn_grid_U.nc','r')
uvel = fU.variables['vozocrtx'][:]
mu = uvel == 0
uvel_masked = np.ma.array(uvel,mask=mu)
print uvel.shape
# Out:
# (6, 40, 898, 398)
# (6, 40, 898, 398)

# %%
fV = NC.Dataset('../Basic6/5mn_grid_V.nc','r')
vvel = fV.variables['vomecrty'][:]
mv = vvel == 0
vvel_masked = np.ma.array(vvel,mask=mv)

# %%
plt.pcolormesh(sal_masked[5,0,375:500,225:350])
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x113a95908>

# %%
plt.pcolormesh(vvel_masked[5,0,325:375,275:325])
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x115c71320>

# %%
plt.figure(figsize=(5,7))
plt.pcolormesh(sal_masked[5,0])
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x115bb70e0>

# %%
plt.pcolormesh(vvel_masked[5,0,275:325,135:185])
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x1172bf908>

# %%
plt.pcolormesh(sal_masked[5,25,385:465,:60])
plt.colorbar()
print sal_masked[0,0,400,4]
# Out:
# 28.4737

# %%
plt.pcolormesh(temp_masked[5,0,385:465,:60])
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x117559950>

# %%
plt.figure(figsize=(9,9))
time=5
plt.quiver(uvel_masked[time,0,385:465,:60],vvel_masked[time,0,385:465,:60])
print np.sqrt(uvel_masked[time,0,410,5]**2+vvel_masked[time,0,410,5]**2)
# Out:
# 1.39096445439e-05

# %%
plt.pcolormesh(np.arange(0,50),-depth[:33],vvel[0,:33,410,0:50])
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x117721440>

# %%
print depth.shape
# Out:
# (40,)
